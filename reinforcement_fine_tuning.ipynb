# %% [markdown]
# # Make gpt-oss play games with Reinforcement Learning
#
# This notebook demonstrates how you make `gpt-oss` play the 2048 game autonomously by using reinforcement learning (RL).
#
# We will train `gpt-oss-20b` using [Unsloth](https://github.com/unslothai/unsloth) to develop a strategy for playing 2048. The strategy will run until the game ends, and the model will be rewarded or penalized based on whether it wins or loses.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f9/2048_win.png/500px-2048_win.png" width=300 />

# %% [markdown]
# # Installation
# To run `gpt-oss-20b` RL on a free Google Colab instance, we’ll use the GRPO algorithm along with [Unsloth](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning), an open-source tool that enables less VRAM usage and faster training.

# %% [markdown]
# We'll load gpt-oss-20b and set some parameters:
# * `max_seq_length = 768` The maximum context length of the model. Increasing it will use more memory, and 768 was the maximum we found to fit on a free 15GB Tesla T4 machine
# * `lora_rank = 4` The larger this number, the smarter the RL process, but the slower and more memory usage
# * `load_in_4bit = True` Uses quantization to reduce memory usage by 75% without reducing accuracy that much. `load_in_16bit` will be faster but will need a 80GB GPU (H100, B200)
# * `offload_embedding = True` Unsloth optimization which moves the embedding to CPU RAM, reducing VRAM by 1GB

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 768 # Can increase for longer RL output
lora_rank = 4        # Larger rank = smarter, but slower
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gpt-oss-20b", # unsloth/gpt-oss-20b-BF16 for H100s
    max_seq_length = max_seq_length,
    load_in_4bit = True,      # False for LoRA 16bit. Choose False on H100s
    offload_embedding = True, # Reduces VRAM by 1GB
)
# Out:
# ==((====))==  Unsloth 2025.12.9: Fast Gpt_Oss patching. Transformers: 4.56.2.
#    \\   /|    NVIDIA GeForce RTX 5080. Num GPUs = 1. Max memory: 15.447 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.1+cu128. CUDA: 12.0. CUDA Toolkit: 12.8. Triton: 3.5.1
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Unsloth: Offloading embeddings to RAM to save 1.08 GB.

# %% [markdown]
# To do efficient RL, we will use LoRA, which allows us to only add 1 to 5% of extra weights to the model for fine-tuning purposes. This allows us to save memory usage by 60% while retaining most accuracy. Read Unsloth's [gpt-oss RL Guide](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning) for more details.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha = lora_rank*2, # *2 speeds up training
    use_gradient_checkpointing = "unsloth", # Reduces memory usage
    random_state = 3407,
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %% [markdown]
# # 2048 game
#
# We used GPT-5 to create a variant of the 2048 game. It should output the current game board state, and allow us to advance the game board state with 1 action (up, down, left, right).

# %%
#@title (Collapsible) 2048 Game Implementation
from dataclasses import dataclass, field
from typing import List, Tuple, Optional
import random
import copy

def _compress_and_merge_row_left(row: List[int]) -> Tuple[List[int], int, bool]:
    n = len(row)
    tiles = [x for x in row if x != 0]
    gained = 0
    i = 0
    merged = []
    while i < len(tiles):
        if i + 1 < len(tiles) and tiles[i] == tiles[i + 1]:
            v = tiles[i] * 2
            gained += v
            merged.append(v)
            i += 2
        else:
            merged.append(tiles[i])
            i += 1
    merged += [0] * (n - len(merged))
    changed = merged != row
    return merged, gained, changed

def _move_left(board: List[List[int]]) -> Tuple[List[List[int]], int, bool]:
    changed_any = False
    total_gain = 0
    new_board = []
    for row in board:
        new_row, gained, changed = _compress_and_merge_row_left(row)
        new_board.append(new_row)
        total_gain += gained
        changed_any = changed_any or changed
    return new_board, total_gain, changed_any

def _move_right(board: List[List[int]]) -> Tuple[List[List[int]], int, bool]:
    changed_any = False
    total_gain = 0
    new_board = []
    for row in board:
        rev = list(reversed(row))
        new_rev, gained, changed = _compress_and_merge_row_left(rev)
        new_row = list(reversed(new_rev))
        new_board.append(new_row)
        total_gain += gained
        changed_any = changed_any or changed
    return new_board, total_gain, changed_any

def _transpose(board: List[List[int]]) -> List[List[int]]:
    return [list(row) for row in zip(*board)]

def _move_up(board: List[List[int]]) -> Tuple[List[List[int]], int, bool]:
    t = _transpose(board)
    moved, gain, changed = _move_left(t)
    return _transpose(moved), gain, changed

def _move_down(board: List[List[int]]) -> Tuple[List[List[int]], int, bool]:
    t = _transpose(board)
    moved, gain, changed = _move_right(t)
    return _transpose(moved), gain, changed

def _empty_cells(board: List[List[int]]) -> List[Tuple[int, int]]:
    size = len(board)
    return [(r, c) for r in range(size) for c in range(size) if board[r][c] == 0]

def _can_move(board: List[List[int]]) -> bool:
    if _empty_cells(board):
        return True
    size = len(board)
    for r in range(size):
        for c in range(size - 1):
            if board[r][c] == board[r][c + 1]:
                return True
    for r in range(size - 1):
        for c in range(size):
            if board[r][c] == board[r + 1][c]:
                return True
    return False

@dataclass
class GameBoard:
    size: int
    seed: Optional[int] = None
    target: int = 2048
    probability_fours: float = 0.10 # originally spawns (4) 10% of the time!
    _rng: random.Random = field(init=False, repr=False)
    _board: List[List[int]] = field(init=False, repr=False)
    _score: int = field(default=0, init=False, repr=False)
    _state: str = field(default="ongoing", init=False, repr=False)

    def __post_init__(self):
        if self.size < 2:
            raise ValueError("Board size must be at least 2.")
        self._rng = random.Random(self.seed)
        self._board = [[0 for _ in range(self.size)] for _ in range(self.size)]
        self._add_random_tile()
        self._add_random_tile()
        self._update_state_after_change()

    class _BoardView:
        def __init__(self, game: "GameBoard"):
            self._game = game
        def __iter__(self):
            return iter(self._game._board)
        def __len__(self):
            return len(self._game._board)
        def __getitem__(self, idx):
            return self._game._board[idx]
        def __repr__(self) -> str:
            return repr(self._game._board)
        __str__ = __repr__
        def do_action(self, key: str) -> None:
            self._game.do_action(key)
        def state(self) -> str:
            return self._game.state()
        def pretty(self, colors: bool = True, border: bool = True, dot_for_zero: bool = True) -> str:
            return self._game._render_pretty(colors=colors, border=border, dot_for_zero=dot_for_zero)

    def board(self) -> "_BoardView":
        return GameBoard._BoardView(self)
    def state(self) -> str:
        return self._state
    def score(self) -> int:
        return self._score
    def do_action(self, key: str) -> None:
        if self._state != "ongoing":
            return
        if not isinstance(key, str) or len(key) == 0:
            self._state = "failed"
            return
        k = key.strip().lower()
        if k == "q":
            self._state = "failed"
            return
        move_map = {"a": _move_left, "d": _move_right, "w": _move_up, "s": _move_down}
        if k not in move_map:
            self._state = "failed"
            return
        mover = move_map[k]
        new_board, gain, changed = mover(self._board)
        if changed:
            self._board = new_board
            self._score += gain
            self._add_random_tile()
        self._update_state_after_change()
    def _add_random_tile(self) -> bool:
        empties = _empty_cells(self._board)
        if not empties:
            return False
        r, c = self._rng.choice(empties)
        self._board[r][c] = 4 if self._rng.random() < self.probability_fours else 2
        return True
    def _update_state_after_change(self) -> None:
        if any(self.target in row for row in self._board):
            self._state = "success"
            return
        if not _can_move(self._board):
            self._state = "failed"
            return
        self._state = "ongoing"
    def _render_pretty(self, colors: bool = True, border: bool = True, dot_for_zero: bool = True) -> str:
        """
        Pretty-print the board with colors that scale from 0 up to self.target.
        Uses ANSI 256-color codes (works in most terminals). Set colors=False to disable.
        """
        import math

        b = self._board
        mx = max((max(row) for row in b), default=0)
        cell_w = max(3, len(str(mx)))

        RESET = "\x1b[0m"

        # A smooth-ish gradient from cool → warm
        # (blue/cyan/green → yellow/orange/red). Tweak or expand as you like.
        GRAD = [33, 39, 45, 51, 50, 49, 48, 47, 46, 82, 118, 154, 190, 226, 220, 214, 208, 202, 196]
        ZERO_FG = 239  # dim gray

        def color_code(v: int) -> str:
            if not colors:
                return ""
            if v == 0:
                return f"\x1b[38;5;{ZERO_FG}m"
            # Normalize by exponent relative to target: r in [0,1]
            t = max(2, self.target)  # safety; avoid log2(1)
            # Guard: if v is not a power of two or is <1, handle gracefully
            try:
                r = max(0.0, min(1.0, math.log2(v) / math.log2(t)))
            except ValueError:
                r = 0.0
            idx = int(round(r * (len(GRAD) - 1)))
            return f"\x1b[38;5;{GRAD[idx]}m"

        def fmt(v: int) -> str:
            s = "." if (v == 0 and dot_for_zero) else str(v)
            s = s.rjust(cell_w)
            return color_code(v) + s + (RESET if colors else "")

        def hline(left: str, mid: str, right: str) -> str:
            return left + mid.join("─" * cell_w for _ in range(self.size)) + right

        rows = []
        if border:
            rows.append(hline("┌", "┬", "┐"))
        for r in range(self.size):
            content = "│".join(fmt(v) for v in b[r])
            rows.append(("│" + content + "│") if border else content)
            if border:
                rows.append(hline("└" if r == self.size - 1 else "├",
                                "┴" if r == self.size - 1 else "┼",
                                "┘" if r == self.size - 1 else "┤"))
        return "\n".join(rows)

# %% [markdown]
# For example let's create a board of size 5 X 5 and set the target to 8 instead of 2048.
#
# **[NOTE]** 2048 originally spawns a (4) 10% of the time! We can disable this for harder games. See [Wikipedia page](https://en.wikipedia.org/wiki/2048_(video_game)) for more details.

# %%
game = GameBoard(size = 5, seed = 42, target = 8, probability_fours = 0.10)
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  2│  .│  .│  .│  2│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game
# Out:
# GameBoard(size=5, seed=42, target=8, probability_fours=0.1)

# %% [markdown]
# We'll use WASD for the action space:
#
# ```
#    W
# A  S  D
# ```
# Also `game.state()` will say `success` if we succeeded in getting the target!

# %%
game.do_action("A")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  2│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  4│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game.do_action("W")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  4│  .│  2│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  2│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game.do_action("D")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  .│  .│  .│  4│  2│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  2│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  4│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game.do_action("W")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  4│  .│  .│  4│  4│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  4│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game.do_action("D")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  .│  .│  2│  4│  8│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  4│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ success

# %% [markdown]
# If we do some other action that's not part of the action space, we will get an error, and the game will not accept anymore actions.

# %%
game = GameBoard(size = 3, seed = 4276, target = 8, probability_fours = 0.10)
game.do_action("XYZ") # Not in WASD
game.do_action("W")  # Doesn't do anything
game.do_action("A")  # Doesn't do anything
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┐
# │  .│  .│  .│
# ├───┼───┼───┤
# │  .│  2│  .│
# ├───┼───┼───┤
# │  .│  .│  4│
# └───┴───┴───┘ failed

# %% [markdown]
# # RL Environment Setup
#
# We'll set up a function to accept some strategy that'll emit an action within `WASD` and check the game state.
#
# We'll also add a timer to only execute the stratgegy for 2 seconds maximum, otherwise it might never terminate!

# %%
from typing import Callable
from unsloth import execute_with_time_limit

def _execute_strategy(strategy : Callable, game : GameBoard):
    assert callable(strategy)

    steps = 0
    while game.state() == "ongoing":
        action = strategy(list(game.board()))
        steps += 1
        if type(action) is not str:
            return steps, "failed"
        game.do_action(action)
    return steps, game.state()

@execute_with_time_limit(2)
def execute_strategy(strategy : Callable, game : GameBoard):
    return _execute_strategy(strategy, game)

# %% [markdown]
# Let's make a generic strategy to just hit `W`. We should expect this generic strategy to fail:

# %%
def always_move_left(board):
    return "W"

game = GameBoard(size = 8, seed = 42, target = 2048, probability_fours = 0.10)
try:
    execute_strategy(always_move_left, game)
except TimeoutError as e:
    print(f"Timed out with error = {str(e)}")
# Out:
# Timed out with error = Timed out after 2s

# %% [markdown]
# To allow longer strategies for gpt-oss-20b Reinforcement Learning, we shall allow a 5 second timer.

# %%
@execute_with_time_limit(5)
def execute_strategy(strategy : Callable, game : GameBoard):
    return _execute_strategy(strategy, game)

# %% [markdown]
# # Code Execution
#
# To execute and create a new Python function, we first have to check if the function does not call other global variables or cheat. This is called `countering reward hacking` since we don't want the function to cheat.
#
# For example the below piece of code is fine, since it only imports Python level functions. We use `check_python_modules`:

# %%
from unsloth import check_python_modules

sample = """
def strategy(board):
    import math
    from typing import Callable
    return "W"
"""
ok, info = check_python_modules(sample)
print("Only Python imports?", ok)
print(info)
# Out:
# Only Python imports? True
# {'stdlib': ['math', 'typing'], 'non_stdlib': [], 'relative_imports': 0}

# %% [markdown]
# For the below piece of code, since we import `numpy`, we should not allow the execution:

# %%
sample = """
def strategy(board):
    from numpy import matmul
    return "W"
"""
ok, info = check_python_modules(sample)
print("Only Python imports?", ok)
print(info)
# Out:
# Only Python imports? False
# {'stdlib': [], 'non_stdlib': ['numpy'], 'relative_imports': 0}

# %% [markdown]
# We also disallow global variable access. We'll use Unsloth's `create_locked_down_function` function

# %%
from unsloth import create_locked_down_function
function = """
def import_numpy():
    np.matmul
    print("Success")
"""
f = create_locked_down_function(function)
try:
    f()
except Exception as e:
    print(str(e))
# Out:
# name 'np' is not defined

# %%
from unsloth import create_locked_down_function
function = """
def add(a, b):
    def adder(a):
        return a + b
    return adder(b) + b
"""
f = create_locked_down_function(function)
try:
    print(f(10, 20))
except Exception as e:
    print(str(e))
# Out:
# 60

# %% [markdown]
# # Data & RL task setup
#
# We now have to create a prompt to tell the model to create a strategy for the 2048 game. You can customize this to some other task for another RL task.

# %%
prompt = """
Create a new short 2048 strategy using only native Python code.
You are given a list of list of numbers for the current board state.
Output one action for "W", "A", "S", "D" on what is the optimal next step.
Output your new short function in backticks using the format below:
```python
def strategy(board):
    return "W" # Example
```
All helper functions should be inside def strategy. Only output the short function `strategy`.
""".strip()
print(prompt)
# Out:
# Create a new short 2048 strategy using only native Python code.
# You are given a list of list of numbers for the current board state.
# Output one action for "W", "A", "S", "D" on what is the optimal next step.
# Output your new short function in backticks using the format below:
# ```python
# def strategy(board):
#     return "W" # Example
# ```
# All helper functions should be inside def strategy. Only output the short function `strategy`.

# %% [markdown]
# First, let's prompt gpt-oss without RL and see how it goes:

# %%
text = tokenizer.apply_chat_template(
    [{"role": "user", "content": prompt}],
    tokenize = False,
    add_generation_prompt = True,
    reasoning_effort = "low",
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    temperature = 1.0,
    max_new_tokens = 512,
    streamer = TextStreamer(tokenizer, skip_prompt = False),
)
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-12-23
#
# Reasoning: low
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Create a new short 2048 strategy using only native Python code.
# You are given a list of list of numbers for the current board state.
# Output one action for "W", "A", "S", "D" on what is the optimal next step.
# Output your new short function in backticks using the format below:
# ```python
# def strategy(board):
#     return "W" # Example
# ```
# All helper functions should be inside def strategy. Only output the short function `strategy`.<|end|><|start|>assistant<|channel|>analysis<|message|>Need to implement simple strategy: maybe choose move that leads to max tile? We'll just return first move that is not blocked? Simplify: scan moves priority up, left, down, right. We'll check if move changes board. Let's write.<|end|><|start|>assistant<|channel|>final<|message|>```python
#
# def strategy(board):
#     import copy
#     def can_move(b, action):
#         b2 = [row[:][:] for rowrow in b]
#        <|call|>
# ```
# <|return|>

# %% [markdown]
# # Reward functions
#
# We now design a `extract_function` function which simply extracts the function wrapped in 3 back ticks.
#
# And 3 reward functions:
#
# 1. `function_works` which rewards the model if the strategy is a valid Python function.
# 2. `no_cheating` which checks if the function imported other modules, and if it did, we penalize it.
# 3. `strategy_succeeds` which checks if the game strategy actually succeeds in attaining 2048 after running the auto-generated strategy.

# %%
def extract_function(text):
    if text.count("```") >= 2:
        first = text.find("```") + 3
        second = text.find("```", first)
        fx = text[first : second].strip()
        fx = fx.removeprefix("python\n")
        fx = fx[fx.find("def"):]
        if fx.startswith("def strategy(board):"): return fx
    return None
print(extract_function(prompt))
# Out:
# def strategy(board):
#     return "W" # Example

# %% [markdown]
# Below is our `function_works` reward function which uses Python's `exec` but guarded by not allowing leakage of local and global variables. We can also use `check_python_modules` first to check if there are errors before even executing the function:

# %%
ok, info = check_python_modules("def a")
ok, info
# Out:
# (False,
#  {'error': "SyntaxError: expected '(' (<unknown>, line 1)",
#   'stdlib': [],
#   'non_stdlib': [],
#   'relative_imports': 0})

# %%
def function_works(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if function is not None:
            ok, info = check_python_modules(function)
        if function is None or "error" in info:
            score = -2.0
        else:
            try:
                new_strategy = create_locked_down_function(function)
                score = 1.0
            except:
                score = -0.5
        scores.append(score)
    return scores

# %% [markdown]
# `no_cheating` checks if the function cheated since it might have imported Numpy or other functions:

# %%
def no_cheating(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if function is not None:
            ok, info = check_python_modules(function)
            scores.append(1.0 if ok else -20.0) # Penalize heavily!
        else:
            scores.append(-1.0) # Failed creating function
    return scores

# %% [markdown]
# Next `strategy_succeeds` checks if the strategy actually allows the game to terminate. Imagine if the strategy simply returned "W" which would fail after a time limit of 10 seconds.
#
# We also add a global `PRINTER` to print out the strategy and board state.

# %%
import numpy as np
global PRINTER
PRINTER = 0
def strategy_succeeds(completions, **kwargs):
    global PRINTER
    scores = []
    # Generate a random game board with seed
    seed = np.random.randint(10000)
    for completion in completions:
        printed = False
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if PRINTER % 5 == 0:
            printed = True
            print(function)
        PRINTER += 1
        if function is not None:
            ok, info = check_python_modules(function)
        if function is None or "error" in info:
            scores.append(0)
            continue
        try:
            new_strategy = create_locked_down_function(function)
        except:
            scores.append(0)
            continue
        try:
            game = GameBoard(size = 6, seed = seed, target = 2048, probability_fours = 0.10)
            steps, game_state = execute_strategy(new_strategy, game)
            print(f"Steps = {steps} State = {game_state}")
            if printed is False:
                print(function)
            print(game.board().pretty())
            if game_state == "success":
                scores.append(20.0) # Success - massively reward!
            else:
                scores.append(2.0) # Failed but function works!
        except TimeoutError as e:
            print("Timeout")
            scores.append(-1.0) # Failed with timeout
        except Exception as e:
            print(f"Exception = {str(e)}")
            scores.append(-3.0) # Failed
    return scores

# %% [markdown]
# We'll now create the dataset which includes a replica of our prompt. Remember to add a reasoning effort of low! You can choose high reasoning mode, but this'll only work on more memory GPUs like H100s.

# %%
from datasets import Dataset
dataset = Dataset.from_list([{"prompt" : [{"role": "user", "content": prompt.strip()}], "answer" : 0, "reasoning_effort": "low"}]*1000)
maximum_length = len(tokenizer.apply_chat_template([{"role": "user", "content": prompt.strip()}], add_generation_prompt = True))
print(maximum_length)
dataset[0]
# Out:
# 181
# {'prompt': [{'content': 'Create a new short 2048 strategy using only native Python code.\nYou are given a list of list of numbers for the current board state.\nOutput one action for "W", "A", "S", "D" on what is the optimal next step.\nOutput your new short function in backticks using the format below:\n```python\ndef strategy(board):\n    return "W" # Example\n```\nAll helper functions should be inside def strategy. Only output the short function `strategy`.',
#    'role': 'user'}],
#  'answer': 0,
#  'reasoning_effort': 'low'}

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations! We also support GSPO, GAPO, Dr GRPO and more! Go the Unsloth [Reinforcement Learning Docs](https://docs.unsloth.ai/get-started/reinforcement-learning-rl-guide) for more options.

# %%
max_prompt_length = maximum_length + 1 # + 1 just in case!
max_completion_length = max_seq_length - max_prompt_length

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    temperature = 1.0,
    learning_rate = 5e-5,
    weight_decay = 0.01,
    warmup_ratio = 0.1,
    lr_scheduler_type = "linear",
    optim = "adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 2, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_completion_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 1000,
    save_steps = 100,
    report_to = "none", # Can use Weights & Biases, TrackIO
    output_dir = "outputs",

    # For optional training + evaluation
    # fp16_full_eval = True,
    # per_device_eval_batch_size = 4,
    # eval_accumulation_steps = 1,
    # eval_strategy = "steps",
    # eval_steps = 1,
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` * `gradient_accumulation_steps` * `world_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 2

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
# For optional training + evaluation
# new_dataset = dataset.train_test_split(test_size = 0.01)

trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        function_works,
        no_cheating,
        strategy_succeeds,
    ],
    args = training_args,
    train_dataset = dataset,

    # For optional training + evaluation
    # train_dataset = new_dataset["train"],
    # eval_dataset = new_dataset["test"],
)

# %% [markdown]
# And let's train the model!
#
# **NOTE** A T4 free GPU might take 5 minutes for one generation sadly since it's an old GPU - A100 or H100 will be much faster!

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,000 | Num Epochs = 1 | Total steps = 1,000
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 1 x 1) = 2
#  "-____-"     Trainable parameters = 1,990,656 of 20,916,747,840 (0.01% trained)
# `generation_config` default values have been modified to match model-specific defaults: {'max_length': 131072}. If this is not desired, please set these values explicitly.
# Unsloth: Will smartly offload gradients to save VRAM!
# None
# Timeout
#     <div>
#
#       <progress value='58' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  58/1000 53:49 < 15:05:24, 0.02 it/s, Epoch 0.06/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / function_works / mean</th>
#       <th>rewards / function_works / std</th>
#       <th>rewards / no_cheating / mean</th>
#       <th>rewards / no_cheating / std</th>
#       <th>rewards / strategy_succeeds / mean</th>
#       <th>rewards / strategy_succeeds / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>2.828427</td>
#       <td>457.500000</td>
#       <td>329.000000</td>
#       <td>586.000000</td>
#       <td>0.500000</td>
#       <td>329.000000</td>
#       <td>329.000000</td>
#       <td>329.000000</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>2.121320</td>
#       <td>0.000000</td>
#       <td>1.414214</td>
#       <td>-0.500000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>-3.000000</td>
#       <td>0.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-2.000000</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.414214</td>
#       <td>405.000000</td>
#       <td>342.000000</td>
#       <td>468.000000</td>
#       <td>0.000000</td>
#       <td>405.000000</td>
#       <td>342.000000</td>
#       <td>468.000000</td>
#       <td>0.003346</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>-2.000000</td>
#       <td>1.414214</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>-3.000000</td>
#       <td>0.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000690</td>
#       <td>-2.000000</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>2.828427</td>
#       <td>540.500000</td>
#       <td>495.000000</td>
#       <td>586.000000</td>
#       <td>0.500000</td>
#       <td>495.000000</td>
#       <td>495.000000</td>
#       <td>495.000000</td>
#       <td>0.005757</td>
#       <td>-0.500000</td>
#       <td>2.121320</td>
#       <td>0.000000</td>
#       <td>1.414214</td>
#       <td>-0.500000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>2.828427</td>
#       <td>508.500000</td>
#       <td>431.000000</td>
#       <td>586.000000</td>
#       <td>0.500000</td>
#       <td>431.000000</td>
#       <td>431.000000</td>
#       <td>431.000000</td>
#       <td>0.006292</td>
#       <td>-0.500000</td>
#       <td>2.121320</td>
#       <td>0.000000</td>
#       <td>1.414214</td>
#       <td>-0.500000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>-2.000000</td>
#       <td>1.414214</td>
#       <td>537.500000</td>
#       <td>489.000000</td>
#       <td>586.000000</td>
#       <td>0.500000</td>
#       <td>489.000000</td>
#       <td>489.000000</td>
#       <td>489.000000</td>
#       <td>0.001083</td>
#       <td>-0.500000</td>
#       <td>2.121320</td>
#       <td>0.000000</td>
#       <td>1.414214</td>
#       <td>-1.500000</td>
#       <td>2.121320</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>309.000000</td>
#       <td>214.000000</td>
#       <td>404.000000</td>
#       <td>0.000000</td>
#       <td>309.000000</td>
#       <td>214.000000</td>
#       <td>404.000000</td>
#       <td>0.003714</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>-3.000000</td>
#       <td>0.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000757</td>
#       <td>-2.000000</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>-2.000000</td>
#       <td>1.414214</td>
#       <td>535.500000</td>
#       <td>485.000000</td>
#       <td>586.000000</td>
#       <td>0.500000</td>
#       <td>485.000000</td>
#       <td>485.000000</td>
#       <td>485.000000</td>
#       <td>0.001234</td>
#       <td>-0.500000</td>
#       <td>2.121320</td>
#       <td>0.000000</td>
#       <td>1.414214</td>
#       <td>-1.500000</td>
#       <td>2.121320</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-3.000000</td>
#       <td>0.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000530</td>
#       <td>-2.000000</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.414214</td>
#       <td>535.500000</td>
#       <td>486.000000</td>
#       <td>585.000000</td>
#       <td>0.000000</td>
#       <td>535.500000</td>
#       <td>486.000000</td>
#       <td>585.000000</td>
#       <td>0.003557</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>-2.000000</td>
#       <td>1.414214</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>400.500000</td>
#       <td>315.000000</td>
#       <td>486.000000</td>
#       <td>0.000000</td>
#       <td>400.500000</td>
#       <td>315.000000</td>
#       <td>486.000000</td>
#       <td>0.003559</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>-3.000000</td>
#       <td>0.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>586.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000439</td>
#       <td>-2.000000</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>-10.500000</td>
#       <td>16.263456</td>
#       <td>329.500000</td>
#       <td>273.000000</td>
#       <td>386.000000</td>
#       <td>0.000000</td>
#       <td>329.500000</td>
#       <td>273.000000</td>
#       <td>386.000000</td>
#       <td>0.002910</td>
#       <td>-0.500000</td>
#       <td>2.121320</td>
#       <td>-9.500000</td>
#       <td>14.849242</td>
#       <td>-0.500000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>-3.000000</td>
#       <td>0.000000</td>
#       <td>586.000000
# Exception = unsupported operand type(s) for +=: 'int' and 'str'
# def strategy(board):
#     def move(board, dir):
#         def compress(row):
#             nonlocal best
#             new = [x for x in row if x]
#             i = 0
#             while i < len(new)-1:
#                 if new[i] == new[i+1]:
#                     new[i] += new[i+1]
#                     new.pop(i+1)
#                 i += 1
#             new += [0]*(4-len(new))
#             return new
#         new_board = [[0]*4 for _ in range(4)]
#         if dir == "A":  # left
#             for i in range(4):
#                 new_board[i] = compress(board[i])
#         elif dir == "D":  # right
#             for i in range(4):
#                 row = compress(board[i][::-1])[::-1]
#                 new_board[i] = row
#         elif dir == "W":  # up
#             for j in range(4):
#                 col = [board[i][j] for i in range(4)]
#                 col = compress(col)
#                 for i in range(4): new_board[i][j] = col[i]
#         else:  # down
#             for j in range(4):
#                 col = [board[i][j] for i in range(4)][::-1]
#                 col = compress(col)[::-1]
#                 for i in range(4): new_board[i][j] = col[i]
#         return new_board
#
#     def score(b):
#         return sum(sum(row) for row in b)
#
#     best, best_dir = -1, None
#     for d in "WASD":
#         nb = move(board, d)
#         if any(any(x==0 for x in row) for row in nb):
#             s = score(nb)
#             if s > best:
#                 best, best_dir = s, d
#     return best_dir or "A"
# Timeout
# Timeout
# def strategy(board):
#     # simple deterministic strategy: prefer moves that keep rows/cols aligned
#     def simulate(board, move):
#         import copy, random
#         def merge_line(line):
#             new = [x for x in line if x]
#             merged = []
#             i = 0
#             while i < len(new):
#                 if i+1 < len(new) and new[i]==new[i+1]:
#                     merged.append(new[i]*2)
#                     i += 2
#                 else:
#                     merged.append(new[i])
#                     i += 1
#             merged += [0]*(4-len(merged))
#             return merged
#         b = copy.deepcopy(board)
#         if move=="W":
#             for col in range(4):
#                 col_vals=[b[row][col] for row in range(4)]
#                 merged=merge_line(col_vals)
#                 for row in range(4):
#                     b[row][col]=merged[row]
#         if move=="S":
#             for col in range(4):
#                 col_vals=[b[row][col] for row in range(3,-1,-1)]
#                 merged=merge_line(col_vals)
#                 for row in range(4):
#                     b[3-row][col]=merged[row]
#         if move=="A":
#             for row in range(4):
#                 merged=merge_line(b[row])
#                 b[row]=merged
#         if move=="D":
#             for row in range(4):
#                 merged=merge_line(b[row][::-1])
#                 b[row]=merged[::-1]
#         return b
#     def score(b):
#         return sum(b[row][col] for row in range(4) for col in range(4))
#     best_move=None
#     best_score=-1
#     for m in "WASD":
#         nb=simulate(board,m)
#         s=score(nb)
#         if s>best_score:
#             best_score=s
#             best_move=m
#     return best_move
# Timeout
# Exception = name 'i' is not defined
# Timeout
# def strategy(board):
#     # Basic heuristic: move towards the largest tile horizontally if possible
#     moves = []
#     # try horizontal moves (left/right)
#     for i in range(2):
#         row = board[i]
#         # count empty cells to the left
#         if row[0] == 0:
#             moves.append('A')
#             break
#         elif row[1] == 0:
#             moves.append('D')
#             break
#     if moves:
#         return moves[0]
#     # otherwise try vertical moves up/down
#     for j in range(2):
#         col = [board[0][j], board[1][j]]
#         if col[0] == 0:
#             return 'W'
#         if col[1] == 0:
#             return 'S'
#     return 'W'
# Timeout
# Exception = list index out of range
# None
# Timeout
# Exception = list index out of range
# Timeout
# def strategy(board):
#     import math
#     height, width = len(board), len(board[0])
#     # helper to check move possibility
#     def can_move(a, b, dir):
#         if dir == "U":
#             return all(a[i][j] >= a[i-1][j] for i in range(1, height) for j in range(width))
#         if dir == "D":
#             return all(a[i][j] >= a[i+1][j] for i in range(height-1) for j in range(width))
#         if dir == "L":
#             return all(a[i][j] >= a[i][j-1] for i in range(height) for j in range(1, width))
#         if dir == "R":
#             return all(a[i][j] >= a[i][j+1] for i in range(height) for j in range(width-1))
#         return False
#
#     # Evaluate each direction for move possibilities
#     dirs = ["U", "D", "L", "R"]
#     for dir in dirs:
#         if can_move(board, board, dir):
#             return {"U":"W","D":"S","L":"A","R":"D"}[dir]
#     return "W"
# Timeout
# Timeout
# None
# Steps = 939 State = failed
# def strategy(board):
#     rows=len(board); cols=len(board[0])
#     moves="WASD"
#     def can_move(dir):
#         b= [row[:] for row in board]
#         if dir=="W":
#             for j in range(cols):
#                 stack=[x for x in [b[i][j] for i in range(rows)] if x]
#                 merged=[]
#                 i=0
#                 while i<len(stack):
#                     if i+1<len(stack) and stack[i]==stack[i+1]:
#                         merged.append(stack[i]*2); i+=2
#                     else:
#                         merged.append(stack[i]); i+=1
#                 for i in range(rows):
#                     b[i][j]=merged[i] if i<len(merged) else 0
#         elif dir=="S":
#             for j in range(cols):
#                 stack=[x for x in [b[i][j] for i in reversed(range(rows))] if x]
#                 merged=[]
#                 i=0
#                 while i<len(stack):
#                     if i+1<len(stack) and stack[i]==stack[i+1]:
#                         merged.append(stack[i]*2); i+=2
#                     else:
#                         merged.append(stack[i]); i+=1
#                 for i in range(rows):
#                     b[rows-1-i][j]=merged[i] if i<len(merged) else 0
#         elif dir=="A":
#             for i in range(rows):
#                 stack=[x for x in b[i] if x]
#                 merged=[]
#                 j=0
#                 while j<len(stack):
#                     if j+1<len(stack) and stack[j]==stack[j+1]:
#                         merged.append(stack[j]*2); j+=2
#                     else:
#                         merged.append(stack[j]); j+=1
#                 b[i]=merged+[0]*(cols-len(merged))
#         else: # "D"
#             for i in range(rows):
#                 stack=[x for x in reversed(b[i]) if x]
#                 merged=[]
#                 j=0
#                 while j<len(stack):
#                     if j+1<len(stack) and stack[j]==stack[j+1]:
#                         merged.append(stack[j]*2); j+=2
#                     else:
#                         merged.append(stack[j]); j+=1
#                 b[i]=[0]*(cols-len(merged))+merged
#         return any(b[i][j]!=board[i][j] for i in range(rows) for j in range(cols))
#     for m in moves:
#         if can_move(m):
#             return m
#     return random.choice(moves)
# ┌───┬───┬───┬───┬───┬───┐
# │128│  8│128│  2│256│  2│
# ├───┼───┼───┼───┼───┼───┤
# │  2│512│ 16│  8│ 64│  8│
# ├───┼───┼───┼───┼───┼───┤
# │256│  2│128│ 64│ 32│ 16│
# ├───┼───┼───┼───┼───┼───┤
# │128│ 32│ 64│ 32│ 16│  8│
# ├───┼───┼───┼───┼───┼───┤
# │ 64│  8│ 32│ 16│  8│  4│
# ├───┼───┼───┼───┼───┼───┤
# │ 16│  2│ 16│  8│  4│  2│
# └───┴───┴───┴───┴───┴───┘
# Timeout
# def strategy(board):
#     # Simple heuristic: pick the move that merges the most tiles
#     def can_move(b, dir):
#         if dir == "W":
#             moves = [(r, c) for r in range(1, 4) for c in range(4) if b[r][c] and b[r-1][c] == b[r][c]]
#         elif dir == "A":
#             moves = [(r, c) for r in range(4) for c in range(1, 4) if b[r][c] and b[r][c-1] == b[r][c]]
#         elif dir == "S":
#             moves = [(r, c) for r in range(3, -1, -1) for c in range(4) if b[r][c] and b[r+1][c] == b[r][c]]
#         else:  # dir == "D"
#             moves = [(r, c) for r in range(4) for c in range(3, -1, -1) if b[r][c] and b[r][c+1] == b[r][c]]
#         return len(moves)
#
#     best = max(("W","A","S","D"), key=lambda d: can_move(board, d))
#     return best
# Timeout
# Timeout
# Timeout
# Timeout
# def strategy(board):
#     # simple heuristic: try to find a move that merges the largest possibility
#     import copy
#
#     height = len(board)
#     width = len(board[0]) if height else 0
#
#     def move_ok(b, dir):
#         # simulate moving dir, return new board
#         if dir == "W":
#             new_board = []
#             for col in range(width):
#                 stack = []
#                 for row in reversed(range(height)):
#                     if b[row][col] != 0:
#                         stack.append(b[row][col])
#                 merged = []
#                 i = 0
#                 while i < len(stack):
#                     if i + 1 < len(stack) and stack[i] == stack[i+1]:
#                         merged.append(stack[i]*2)
#                         i += 2
#                     else:
#                         merged.append(stack[i])
#                         i += 1
#                 # pad zeros
#                 merged += [0]*(height-len(merged))
#                 new_board.append(merged[::-1])
#             return [col[i] for col in new_board], True
#         # other directions omitted for brevity
#         return None, False
#
#     best_score = -1
#     best_move = "W"
#     for dir in ["W","A","S","D"]:
#         new_board, ok = move_ok(board, dir)
#         if not ok:
#             continue
#         # score = number of non-zero tiles
#         score = sum(1 for row in new_board for val in row if val != 0)
#         if score > best_score:
#             best_score = score
#             best_move = dir
#     return best_move
# Exception = 'int' object is not iterable
# Exception = list index out of range
# def strategy(board):
#     import math, random
#     rows = len(board)
#     cols = len(board[0])
#
#     def can_move(dir):
#         new = copy_move(board, dir)
#         return new != board
#
#     def copy_move(b, dir):
#         new = [row[:] for row in b]
#         if dir == "W":
#             for j in range(cols):
#                 combo = [x for row in new for x in row if x][j]
#         return new
#
#     # Simple heuristic: if tiles can combine, move that merges
#     best = None
#     for dir in "WASD":
#         if can_move(dir):
#             best = dir
#             break
#     return best if best else random.choice("WASD")
# Exception = list index out of range
# Timeout
# Timeout
# Timeout
# def strategy(board):
#     # Simple heuristic: try moves in order and return the first that changes the board.
#     import copy
#     moves = "WASD"
#     best = None
#     for m in moves:
#         # simulate move
#         b = copy.deepcopy(board)
#         if m == "W":
#             # move up
#             for col in range(4):
#                 vals = [b[r][col] for r in range(4) if b[r][col] > 0]
#                 for r in range(4):
#                     b[r][col] = vals[r] if r < len(vals) else 0
#         elif m == "S":
#             # move down
#             for col in range(4):
#                 vals = [b[r][col] for r in range(4) if b[r][col] > 0][::-1]
#                 for r in range(4):
#                     b[3-r][col] = vals[r] if r < len(vals) else 0
#         elif m == "A":
#             # move left
#             for r in range(4):
#                 vals = [b[r][c] for c in range(4) if b[r][c] > 0]
#                 for c in range(4):
#                     b[r][c] = vals[c] if c < len(vals) else 0
#         elif m == "D":
#             # move right
#             for r in range(4):
#                 vals = [b[r][c] for c in range(4) if b[r][c] > 0][::-1]
#                 for c in range(4):
#                     b[r][3-c] = vals[c] if c < len(vals) else 0
#         # compare boards
#         if b != board:
#             return m
#     # if no move changes board, return any
#     return "W"
# Timeout
# Timeout
# Timeout
# Timeout
# def strategy(board):
#     # board is a list of 4 lists of size 4 with values 0,2,4,...
#     def score(b, dir):
#         n = 4
#         m = [[0]*n for _ in range(n)]
#         for i in range(n):
#             for j in range(n):
#                 v = b[i][j]
#                 if v==0: continue
#                 if dir=="W":
#                     y = i
#                     while y>0 and m[y-1][j]==0:
#                         y-=1
#                     while y>0 and m[y-1][j]==v:
#                         y-=1; v*=2
#                     m[y][j]=v
#                 elif dir=="A":
#                     x=j
#                     while x>0 and m[i][x-1]==0:
#                         x-=1
#                     while x>0 and m[i][x-1]==v:
#                         x-=1; v*=2
#                     m[i][x]=v
#                 elif dir=="S":
#                     y=i
#                     while y<n-1 and m[y+1][j]==0:
#                         y+=1
#                     while y<n-1 and m[y+1][j]==v:
#                         y+=1; v*=2
#                     m[y][j]=v
#                 else:  # "D"
#                     x=j
#                     while x<n-1 and m[i][x+1]==0:
#                         x+=1
#                     while x<n-1 and m[i][x+1]==v:
#                         x+=1; v*=2
#                     m[i][x]=v
#         empty = sum(1 for i in range(n) for j in range(n) if m[i][j]==0)
#         return empty
#     best='',-1
#     for d in "WASD":
#         e=score(board,d)
#         if e>best[1]:
#             best=d,e
#     return best[0]
# Timeout
# Timeout
# Timeout
# Timeout
# Timeout
# def strategy(board):
#     import copy
#     dirs = {"W":(-1,0),"A":(0,-1),"S":(1,0),"D":(0,1)}
#     def move(b,dx,dy):
#         n=len(b);new=[[0]*n for _ in range(n)]
#         for i in range(n):
#             for j in range(n):
#                 if b[i][j]==0: continue
#                 x,y=i,j
#                 while True:
#                     nx,ny=x+dx,y+dy
#                     if not (0<=nx<n and 0<=ny<n): break
#                     if new[nx][ny]==0:
#                         new[nx][ny]=b[i][j];break
#                     if new[nx][ny]==b[i][j]:
#                         new[nx][ny]*=2;break
#                     break
#         return new
#     def score(b):
#         s=0
#         for row in b:
#             s+=row.count(0)
#         return s
#     best=None;best_score=-1
#     for m,(dx,dy) in dirs.items():
#         nb=move(copy.deepcopy(board),dx,dy)
#         if score(nb)>best_score:
#             best_score=score(nb);best=m
#     return best
# Timeout
# Timeout
# Timeout
# Timeout
# Timeout
# def strategy(board):
#     # Helper to rotate board clockwise n times
#     def rotate(b, times):
#         for _ in range(times):
#             b = list(zip(*b[::-1]))
#         return [list(row) for row in b]
#
#     # Merge one row left
#     def merge_row(r):
#         new = [x for x in r if x!=0]
#         res = []
#         i=0
#         while i < len(new):
#             if i+1<len(new) and new[i]==new[i+1]:
#                 res.append(new[i]*2)
#                 i+=2
#             else:
#                 res.append(new[i])
#                 i+=1
#         res += [0]*(len(r)-len(res))
#         return res
#
#     # Score: total sum of tiles after move
#     def simulate(b, move):
#         b = [row[:] for row in b]
#         if move=='A':
#             for i in range(len(b)):
#                 b[i] = merge_row(b[i])
#         elif move=='D':
#             for i in range(len(b)):
#                 b[i] = merge_row(b[i][::-1])[::-1]
#         elif move=='W':
#             b = rotate(b,1)
#             for i in range(len(b)):
#                 b[i] = merge_row(b[i])
#             b = rotate(b,3)
#         elif move=='S':
#             b = rotate(b,3)
#             for i in range(len(b)):
#                 b[i] = merge_row(b[i])
#             b = rotate(b,1)
#         return sum(sum(row) for row in b)
#
#     best=None
#     best_score=-1
#     for mv in "WASD":
#         # skip if move not possible (no change)
#         new = simulate(board,mv)
#         if new>best_score:
#             best_score=new
#             best=mv
#     return best
# Timeout
# Timeout
# Timeout
# Timeout
# None
# Timeout
# Exception = 'NoneType' object is not iterable
# Timeout
# def strategy(board):
#     # helper to check if a move is possible in a given direction
#     def count_moves(dir):
#         moves = 0
#         n = len(board)
#         for i in range(n):
#             for j in range(n):
#                 r, c = i, j
#                 if dir=="W":
#                     if r>0 and (board[r][c]==0 or board[r][c]==board[r-1][c]): moves+=1
#                 elif dir=="A":
#                     if c>0 and (board[r][c]==0 or board[r][c]==board[r][c-1]): moves+=1
#                 elif dir=="S":
#                     if r<n-1 and (board[r][c]==0 or board[r][c]==board[r+1][c]): moves+=1
#                 elif dir=="D":
#                     if c<n-1 and (board[r][c]==0 or board[r][c]==board[r][c+1]): moves+=1
#         return moves
#
#     best_dir = None
#     best_score = -1
#     for d in "WASD":
#         score = count_moves(d)
#         if score > best_score:
#             best_score = score
#             best_dir = d
#     return best_dir
# Timeout
# Timeout
# Timeout
# Timeout
# Timeout
# None
# Timeout
# Steps = 1104 State = success
# def strategy(board):
#     # board is a list of lists with 0 for empty cells and powers for tiles
#     size = len(board)
#     # Helper to get neighbors
#     def get_neighbors(r, c):
#         dirs = [(0,-1),(0,1),(-1,0),(1,0)]
#         return [(r+dr,c+dc) for dr,dc in dirs if 0<=r+dr<size and 0<=c+dc<size]
#     # Count possible merges for each move
#     def possible_merge_for_move(move):
#         nh = {
#             'W': (lambda r,c: (r-1,c)),
#             'S': (lambda r,c: (r+1,c)),
#             'A': (lambda r,c: (r,c-1)),
#             'D': (lambda r,c: (r,c+1)),
#         }
#         count = 0
#         for r in range(size):
#             for c in range(size):
#                 val = board[r][c]
#                 if val==0: continue
#                 nr, nc = nh[move](r,c)
#                 if 0<=nr<size and 0<=nc<size:
#                     neigh = board[nr][nc]
#                     if neigh==0 or neigh==val:
#                         count += 1
#         return count
#     # Try all moves and pick the one with most possible merges
#     best_move = "W"
#     best_score = -1
#     for m in 'WASD':
#         score = possible_merge_for_move(m)
#         if score > best_score:
#             best_score, best_move = score, m
#     return best_move
# ┌────┬────┬────┬────┬────┬────┐
# │   2│   .│   .│   .│   .│   2│
# ├────┼────┼────┼────┼────┼────┤
# │   8│   4│   .│   .│   .│   .│
# ├────┼────┼────┼────┼────┼────┤
# │   4│  64│   .│   .│   .│   .│
# ├────┼────┼────┼────┼────┼────┤
# │   2│  16│  32│  32│   .│   .│
# ├────┼────┼────┼────┼────┼────┤
# │  16│   8│2048│  32│   8│   .│
# ├────┼────┼────┼────┼────┼────┤
# │   2│   8│ 128│   4│   4│   2│
# └────┴────┴────┴────┴────┴────┘
# def strategy(board):
#     # Helper to clone board
#     def clone(b): return [row[:] for row in b]
#     # Return all possible moves and resulting boards
#     def moves(b):
#         def rotate(b): return [list(reversed(col)) for col in zip(*b)]
#         def merge_row(row):
#             new = [x for x in row if x]
#             for i in range(len(new)-1):
#                 if new[i]==new[i+1]:
#                     new[i]*=2; new.pop(i+1)
#             return new+[0]*(4-len(new))
#         def move_left(b):
#             return [merge_row(row) for row in b]
#         res={}
#         for dir, fn in [('L',move_left),('R',lambda b:[list(reversed(merge_row(list(reversed(r))))) for r in b]),
#                          ('U',lambda b:move_left(rotate(b))),('D',lambda b:move_left(rotate(rotate(rotate(b))))]]:
#             nb=fn(clone(b))
#             if any(0 in r for r in nb):
#                 res[dir]=nb
#         return res
#     board_map=moves(board)
#     if not board_map: return "W"
#     # choose move that gives the maximum number of empty cells
#     best=None; best_empty=-1
#     for dir, nb in board_map.items():
#         empty=sum(row.count(0) for row in nb)
#         if empty>best_empty:
#             best_empty=empty; best=dir
#     return {'L':'A','R':'D','U':'W','D':'S'}[best]
# Timeout
# Timeout
# Timeout
# Steps = 1 State = failed
# def strategy(board):
#     # board is a list of lists with 4 rows and 4 columns
#     # if board is already at goal check return None (not needed here)
#     # simple greedy: prioritize moves that keep moving in the same direction
#     # if possible move left until no more changes else try other directions
#     def can_move(dir):
#         n=4
#         if dir=='L':
#             for i in range(n):
#                 for j in range(1,n):
#                     if board[i][j] and (board[i][j]==board[i][j-1] or board[i][j-1]==0):
#                         return True
#             return False
#         if dir=='R':
#             for i in range(n):
#                 for j in range(n-1):
#                     if board[i][j] and (board[i][j]==board[i][j+1] or board[i][j+1]==0):
#                         return True
#             return False
#         if dir=='U':
#             for j in range(n):
#                 for i in range(1,n):
#                     if board[i][j] and (board[i][j]==board[i-1][j] or board[i-1][j]==0):
#                         return True
#             return False
#         if dir=='D':
#             for j in range(n):
#                 for i in range(n-1):
#                     if board[i][j] and (board[i][j]==board[i+1][j] or board[i+1][j]==0):
#                         return True
#             return False
#     for d in 'LDRU':
#         if can_move(d):
#             return d
#     return 'L'
# ┌───┬───┬───┬───┬───┬───┐
# │  .│  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┼───┤
# │  .│  2│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│  4│
# ├───┼───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┴───┘
# None
# Exception = cannot access local variable 'move' where it is not associated with a value
# Timeout
# None
# Timeout
# Timeout
# Timeout
# Timeout
# def strategy(board):
#     import random
#     def move_possible(b, dir):
#         m = len(b)
#         new = [[0]*m for _ in range(m)]
#         changed = False
#         for i in range(m):
#             vals = [b[i][j] for j in range(m) if b[i][j]!=0]
#             if dir=="W":
#                 vals = merge(vals)
#                 for j in range(m):
#                     new[i][j] = vals[j] if j<len(vals) else 0
#             elif dir=="S":
#                 vals = merge(vals[::-1])
#                 for j in range(m):
#                     new[i][m-1-j] = vals[j] if j<len(vals) else 0
#             elif dir=="A":
#                 vals = merge(vals)
#                 for j in range(m):
#                     new[j][i] = vals[j] if j<len(vals) else 0
#             elif dir=="D":
#                 vals = merge(vals[::-1])
#                 for j in range(m):
#                     new[m-1-j][i] = vals[j] if j<len(vals) else 0
#         return new
#     def merge(v):
#         res=[]
#         i=0
#         while i<len(v):
#             if i+1<len(v) and v[i]==v[i+1]:
#                 res.append(v[i]*2); i+=2
#             else:
#                 res.append(v[i]); i+=1
#         return res
#     def score(b):
#         return sum(sum(row) for row in b)
#     best=None
#     for dir in "WASD":
#         nb=move_possible(board,dir)
#         if nb!=board:
#             sc=score(nb)
#             if best is None or sc>best[0]:
#                 best=(sc,dir)
#     return best[1] if best else random.choice("WASD")
# Timeout
# Timeout
# Timeout
# def strategy(board):
#     # simple heuristic: prefer moves that merge tiles or keep board compact
#     def move_score(b, dir):
#         # simulate step and return number of merges plus tilting to edges
#         import numpy as np
#         m = len(b)
#         board = np.array(b, dtype=int)
#         def shift_row_left(row):
#             nonzero = row[row != 0]
#             new = []
#             i = 0
#             while i < len(nonzero):
#                 if i + 1 < len(nonzero) and nonzero[i] == nonzero[i + 1]:
#                     new.append(nonzero[i]*2)
#                     i += 2
#                 else:
#                     new.append(nonzero[i])
#                     i += 1
#             return np.pad(new, (0, m - len(new)), mode='constant')
#         if dir == "L":
#             new_board = np.array([shift_row_left(row) for row in board])
#         elif dir == "R":
#             new_board = np.array([shift_row_left(row[::-1])[::-1] for row in board])
#         elif dir == "U":
#             new_board = shift_row_left(board.T).T
#         elif dir == "D":
#             new_board = shift_row_left(board.T[::-1]).T[::-1]
#         else:
#             return -1
#         merged = np.sum(new_board != board)
#         return merged
#
#     best = None
#     best_score = -1
#     for d in ["W", "A", "S", "D"]:
#         sc = move_score(board, d)
#         if sc > best_score:
#             best_score = sc
#             best = d
#     return best if best else "A"
# Exception = index can't contain negative values
# Timeout
# Timeout
# Timeout
# def strategy(board):
#     # simple rule: if can merge left -> A, else down if possible, else right, else up
#     def can_merge_left(board):
#         for r in range(4):
#             for c in range(1,4):
#                 if board[r][c]==board[r][c-1]:
#                     return True
#         return False
#     return "A" if can_merge_left(board) else "D"
# Timeout
# Timeout
# Timeout
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 trainer.train()
#
# File /workspaces/nvidia_reinforcement_learning_fine_tuning/unsloth_compiled_cache/UnslothGRPOTrainer.py:55, in prepare_for_training_mode.<locals>.wrapper(self, *args, **kwargs)
#      53 if hasattr(self, 'model') and hasattr(self.model, "for_training"):
#      54     self.model.for_training()
# ---> 55 output = f(self, *args, **kwargs)
#      56 # Return inference mode
#      57 if hasattr(self, 'model') and hasattr(self.model, "for_inference"):
#
# File /workspaces/nvidia_reinforcement_learning_fine_tuning/.venv/lib/python3.11/site-packages/transformers/trainer.py:2328, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326         hf_hub_utils.enable_progress_bars()
#    2327 else:
# -> 2328     return inner_training_loop(
#    2329         args=args,
#    2330         resume_from_checkpoint=resume_from_checkpoint,
#    2331         trial=trial,
#    2332         ignore_keys_for_eval=ignore_keys_for_eval,
#    2333     )
#
# File <string>:323, in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# File <string>:34, in _unsloth_training_step(self, model, inputs, num_items_in_batch)
#
# File /workspaces/nvidia_reinforcement_learning_fine_tuning/.venv/lib/python3.11/site-packages/trl/extras/profiling.py:98, in profiling_decorator.<locals>.wrapper(self, *args, **kwargs)
#      95 @functools.wraps(func)
#      96 def wrapper(self, *args, **kwargs):
#      97     with profiling_context(self, func.__name__):
# ---> 98         return func(self, *args, **kwargs)
#
# File /workspaces/nvidia_reinforcement_learning_fine_tuning/unsloth_compiled_cache/UnslothGRPOTrainer.py:2212, in _UnslothGRPOTrainer._prepare_inputs(self, generation_batch)
#    2209 generate_every = self.args.steps_per_generation * self.num_iterations
#    2210 if self._step % generate_every == 0 or self._buffered_inputs is None:
#    2211     # self._buffered_inputs=None can occur when resuming from a checkpoint
# -> 2212     generation_batch = self._generate_and_score_completions(generation_batch)
#    2213     generation_batch = split_pixel_values_by_grid(generation_batch)
#    2215     try: generation_batch = shuffle_sequence_dict(generation_batch)
#
# File /workspaces/nvidia_reinforcement_learning_fine_tuning/unsloth_compiled_cache/UnslothGRPOTrainer.py:2636, in _UnslothGRPOTrainer._generate_and_score_completions(self, inputs)
#    2631     completions = completions_text
#    2633 # Calculate rewards for each reward function. rewards_per_func aggregates rewards across all processes. This is
#    2634 # important because rewards will be normalized per group, and completions are distributed. We will later slice
#    2635 # rewards_per_func to extract each process's subset.
# -> 2636 rewards_per_func = self._calculate_rewards(inputs, original_prompts, completions, completion_ids_list)
#    2638 # Apply weights to each reward function's output and sum
#    2639 rewards = (rewards_per_func * self.reward_weights.to(device).unsqueeze(0)).nansum(dim=1)
#
# File /workspaces/nvidia_reinforcement_learning_fine_tuning/.venv/lib/python3.11/site-packages/trl/extras/profiling.py:98, in profiling_decorator.<locals>.wrapper(self, *args, **kwargs)
#      95 @functools.wraps(func)
#      96 def wrapper(self, *args, **kwargs):
#      97     with profiling_context(self, func.__name__):
# ---> 98         return func(self, *args, **kwargs)
#
# File /workspaces/nvidia_reinforcement_learning_fine_tuning/unsloth_compiled_cache/UnslothGRPOTrainer.py:2257, in _UnslothGRPOTrainer._calculate_rewards(self, inputs, prompts, completions, completion_ids_list)
#    2255         rewards_per_func[:, i] = reward_func(**reward_inputs).logits[:, 0]  # Shape (B*G,)
#    2256 else:
# -> 2257     output_reward_func = reward_func(
#    2258         prompts=prompts, completions=completions, completion_ids=completion_ids_list, **reward_kwargs
#    2259     )
#    2260     # Convert None values to NaN
#    2261     output_reward_func = [reward if reward is not None else torch.nan for reward in output_reward_func]
#
# Cell In[31], line 30, in strategy_succeeds(completions, **kwargs)
#      28 try:
#      29     game = GameBoard(size = 6, seed = seed, target = 2048, probability_fours = 0.10)
# ---> 30     steps, game_state = execute_strategy(new_strategy, game)
#      31     print(f"Steps = {steps} State = {game_state}")
#      32     if printed is False:
#
# File /workspaces/nvidia_reinforcement_learning_fine_tuning/.venv/lib/python3.11/site-packages/unsloth_zoo/rl_environments.py:479, in execute_with_time_limit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     477 if backend == "signal":
#     478     with time_limit(seconds):
# --> 479         return func(*args, **kwargs)
#     480 elif backend == "process":
#     481     return _run_in_subprocess(func, seconds, args, kwargs,
#     482                               start_method=start_method, kill_grace=kill_grace)
#
# Cell In[20], line 3, in execute_strategy(strategy, game)
#       1 @execute_with_time_limit(5)
#       2 def execute_strategy(strategy : Callable, game : GameBoard):
# ----> 3     return _execute_strategy(strategy, game)
#
# Cell In[18], line 13, in _execute_strategy(strategy, game)
#      11     if type(action) is not str:
#      12         return steps, "failed"
# ---> 13     game.do_action(action)
#      14 return steps, game.state()
#
# Cell In[4], line 141, in GameBoard.do_action(self, key)
#     139     return
#     140 mover = move_map[k]
# --> 141 new_board, gain, changed = mover(self._board)
#     142 if changed:
#     143     self._board = new_board
#
# Cell In[4], line 55, in _move_up(board)
#      53 def _move_up(board: List[List[int]]) -> Tuple[List[List[int]], int, bool]:
#      54     t = _transpose(board)
# ---> 55     moved, gain, changed = _move_left(t)
#      56     return _transpose(moved), gain, changed
#
# Cell In[4], line 34, in _move_left(board)
#      32     new_board.append(new_row)
#      33     total_gain += gained
# ---> 34     changed_any = changed_any or changed
#      35 return new_board, total_gain, changed_any
#
# KeyboardInterrupt:

# %% [markdown]
# <a name="Inference"></a>
# # Inference
# Now let's try the model we just trained!

# %%
text = tokenizer.apply_chat_template(
    [{"role": "user", "content": prompt}],
    tokenize = False,
    add_generation_prompt = True,
    reasoning_effort = "low",
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    temperature = 1.0,
    max_new_tokens = 1024,
    streamer = TextStreamer(tokenizer, skip_prompt = False),
)
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-12-23
#
# Reasoning: low
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Create a new short 2048 strategy using only native Python code.
# You are given a list of list of numbers for the current board state.
# Output one action for "W", "A", "S", "D" on what is the optimal next step.
# Output your new short function in backticks using the format below:
# ```python
# def strategy(board):
#     return "W" # Example
# ```
# All helper functions should be inside def strategy. Only output the short function
# `strategy`.<|end|><|start|>assistant<|channel|>analysis<|message|>We need a heuristic. Use simple logic: prefer moves that merge or open space. Just return first available with highest merge. We'll write code.<|end|><|start|>assistant<|channel|>final<|message|>```python
# def strategy(board):
#     # helper to compute score of a move
#     def move_score(board, direction):
#         import copy
#         b = copy.deepcopy(board)
#         size = len(b)
#         def slide(row):
#             new = [x for x in row if x != 0]
#             res = []
#             i = 0
#             while i < len(new):
#                 if i+1 < len(new) and new[i]==new[i+1]:
#                     res.append(new[i]*2)
#                     i += 2
#                 else:
#                     res.append(new[i])
#                     i += 1
#             return res + [0]*(size-len(res))
#         if direction == 'w':
#             for j in range(size):
#                 col = [b[i][j] for i in range(size)]
#                 new_col = slide(col)
#                 for i in range(size):
#                     b[i][j] = new_col[i]
#         elif direction == 'a':
#             for i in range(size):
#                 b[i] = slide(b[i])
#         elif direction == 's':
#             for j in range(size):
#                 col = [b[i][j] for i in range(size)][::-1]
#                 new_col = slide(col)
#                 for i in range(size):
#                     b[size-1-i][j] = new_col[i]
#         elif direction == 'd':
#             for i in range(size):
#                 b[i] = slide(b[i][::-1])[::-1]
#         score = 0
#         for row in b:
#             for val in row:
#                 if val != 0:
#                     score += val
#         return score
#     best_dir, best_score = None, -1
#     for d in 'wasd':
#         s = move_score(board, d)
#         if s > best_score:
#             best_score = s
#             best_dir = d.upper()
#     return best_dir
# ```<|return|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 or `MXFP4`
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `mxfp4` for MXFP4 (OpenAI's gpt-oss native precision). We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge and push to hub in mxfp4 4bit format
if False:
    model.save_pretrained_merged("finetuned_model", tokenizer, save_method = "mxfp4")
if False:
    model.push_to_hub_merged("repo_id/repo_name", tokenizer, token = "hf...", save_method = "mxfp4")

# Merge and push to hub in 16bit
if False:
    model.save_pretrained_merged("finetuned_model", tokenizer, save_method = "merged_16bit")
if False: # Pushing to HF Hub
    model.push_to_hub_merged("hf/gpt-oss-finetune", tokenizer, save_method = "merged_16bit", token = "")

# %% [markdown]
# # And we're done!
# Congratulations you just learned how to do reinforcement learning with gpt-oss! There were some advanced topics explained in this notebook - to learn more about gpt-oss and RL, there are more docs in Unsloth's [Reinforcement Learning Guide with gpt-oss](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning)
